# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekpottam/CS5542-BigData-Analytics-and-Applications-by-Vivek/blob/master/ICP1_by_Vivek_Pottam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Panopto Link to walk throught of the document :

# %% [markdown]
# https://umkc.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=5228ee4a-c864-4ef7-9bab-ac25017cb0e4

# %% [markdown]
# Import all the required libraries that you are planning to use

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# use read_csv function from pandas to convert the cvs file to pandas DataFrame

# %%
raw_data = pd.read_csv('/content/drive/My Drive/Datasets/BreastCancer/Data.csv')
type(raw_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# to view first 5 and last 5 rows of the raw_data DataFrame

# %%
raw_data
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %% [markdown]
# head function to see top n rows in the dataset

# %%
raw_data.head(10)
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
# 5    843786         M  ...                  0.12440          NaN
# 6    844359         M  ...                  0.08368          NaN
# 7  84458202         M  ...                  0.11510          NaN
# 8    844981         M  ...                  0.10720          NaN
# 9  84501001         M  ...                  0.20750          NaN
#
# [10 rows x 33 columns]

# %% [markdown]
# use simple functions like <dataframe>.columns to list return all the column names

# %%
raw_data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# use describe function to understand the variance of the dataset

# %%
raw_data.describe()
# Out:
#                  id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# count  5.690000e+02   569.000000  ...               569.000000          0.0
# mean   3.037183e+07    14.127292  ...                 0.083946          NaN
# std    1.250206e+08     3.524049  ...                 0.018061          NaN
# min    8.670000e+03     6.981000  ...                 0.055040          NaN
# 25%    8.692180e+05    11.700000  ...                 0.071460          NaN
# 50%    9.060240e+05    13.370000  ...                 0.080040          NaN
# 75%    8.813129e+06    15.780000  ...                 0.092080          NaN
# max    9.113205e+08    28.110000  ...                 0.207500          NaN
#
# [8 rows x 32 columns]

# %% [markdown]
# Check for any null columns by using isnull function

# %%
raw_data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# Check the shape of the dataFrame

# %%
raw_data.shape
# Out:
# (569, 33)

# %% [markdown]
# Because we have identified that there is column called "Unnamed:32" which has all null values, we can go ahead drop it because it is of no use for us in our analysis

# %%
raw_data.drop('Unnamed: 32',axis=1,inplace=True)

# %% [markdown]
# Shape after deletion, columns decreased by 1

# %%
raw_data.shape
# Out:
# (569, 32)

# %%
raw_data.isnull().sum()

# %% [markdown]
# Create a simple Groupby on diagnosis

# %%
raw_data_group_by_diagnosis = raw_data.groupby('diagnosis')

# %%
raw_data_group_by_diagnosis.count()
# Out:
#             id  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# diagnosis                    ...
# B          357          357  ...             357                      357
# M          212          212  ...             212                      212
#
# [2 rows x 31 columns]

# %% [markdown]
# You can also alternatively use searborn to show simple countplot

# %%
sns.countplot(x='diagnosis',data=raw_data)

# %% [markdown]
# Slice and dice the dataset into features vs results to further use it for any analysis if required

# %%
x=raw_data.iloc[:,2:]
#y=raw_data["diagnosis"].map({'M':1,'B':0})
y=raw_data.diagnosis.map({'M':1, 'B':0})

# %%
x
# Out:
#      radius_mean  texture_mean  ...  fractal_dimension_worst  Unnamed: 32
# 0          17.99         10.38  ...                  0.11890          NaN
# 1          20.57         17.77  ...                  0.08902          NaN
# 2          19.69         21.25  ...                  0.08758          NaN
# 3          11.42         20.38  ...                  0.17300          NaN
# 4          20.29         14.34  ...                  0.07678          NaN
# ..           ...           ...  ...                      ...          ...
# 564        21.56         22.39  ...                  0.07115          NaN
# 565        20.13         28.25  ...                  0.06637          NaN
# 566        16.60         28.08  ...                  0.07820          NaN
# 567        20.60         29.33  ...                  0.12400          NaN
# 568         7.76         24.54  ...                  0.07039          NaN
#
# [569 rows x 31 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
list(x)
# Out:
# ['radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst',
#  'Unnamed: 32']

# %% [markdown]
# Heat map to identify the any correlation in features

# %%
sns.heatmap(x.corr(),cbar=True,cmap='Greens',square=True,annot=False,annot_kws={'size': 10}, fmt= '0.1f')
